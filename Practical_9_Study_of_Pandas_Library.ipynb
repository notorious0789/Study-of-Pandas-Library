# %% [markdown]
# <a href="https://colab.research.google.com/github/notorious0789/Study-of-Pandas-Library/blob/main/Practical_9_Study_of_Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 9
# #Title: Study of Pandas Library
# #17 Feb 2026
# #Apoorba Chatterjee
# #PRN: 25070123020
# #ENTC A1

# %%
import pandas as pd

s=pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create DataFrame
data={"Name":['Naman','Smriti','Prateek'],
      "Marks":[98,98,98]}

df=pd.DataFrame(data)
df
# Out:
#       Name  Marks
# 0    Naman     98
# 1   Smriti     98
# 2  Prateek     98

# %%
#df.head() is first 5 entries and df.tail() is last 5 entries

# %%
#Structure of DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
#Display Column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access Individual Column
df['Name']
# Out:
# 0      Naman
# 1     Smriti
# 2    Prateek
# Name: Name, dtype: object

# %%
df['Marks']
# Out:
# 0    98
# 1    98
# 2    98
# Name: Marks, dtype: int64

# %%
#Access specific row
df.loc[1]
# Out:
# Name     Smriti
# Marks        98
# Name: 1, dtype: object

# %%
#Add a new column
df['Grade']=['A','A','A']
df
# Out:
#       Name  Marks Grade
# 0    Naman     98     A
# 1   Smriti     98     A
# 2  Prateek     98     A

# %%
#Update Data in DataFrame
#Change marks of student
df.loc[0,'Marks']=100
df
# Out:
#       Name  Marks Grade
# 0    Naman    100     A
# 1   Smriti     98     A
# 2  Prateek     98     A

# %%
from numpy import True_
#Delete a column
df.drop('Grade',axis=1,inplace=True)
df
# Out:
#       Name  Marks
# 0    Naman    100
# 1   Smriti     98
# 2  Prateek     98

# %%
#Perform Basic Statistical Analysis
df['Marks'].mean()
# Out:
# np.float64(98.66666666666667)

# %%
df['Marks'].max()
# Out:
# 100

# %%
df['Marks'].min()
# Out:
# 98

# %%
#Apply Condition
df[df['Marks']>99]
# Out:
#     Name  Marks
# 0  Naman    100
